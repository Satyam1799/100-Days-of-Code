# %% [markdown]
# <a href="https://colab.research.google.com/github/Satyam1799/100-Days-of-Code/blob/main/Canny_Edge_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
#image read and preprocessing
img = cv2.imread("img.jpg")
#convert into rgb
imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#rgb to grey
imgGray = cv2.cvtColor(imgRGB,cv2.COLOR_RGB2GRAY)
#apply gaussian blur
imgBlur = cv2.GaussianBlur(imgGray,(3,3),0)
plt.title("Original Image")
plt.imshow(imgRGB)

# %%
#Canny edge detection
#using thresholt parameter to detect edges
edges = cv2.Canny(image = imgBlur,threshold1 = 100, threshold2 = 200)
edges = cv2.cvtColor(edges,cv2.COLOR_BGR2RGB)
plt.imshow(edges)
